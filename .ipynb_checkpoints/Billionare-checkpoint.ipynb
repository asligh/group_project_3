# %%
import psycopg2
import pandas as pd
from sqlalchemy import create_engine

billionaire_metadata_path = "data/forbes_billionaires_geo.csv"

# Read the billionaire data
billionaire_metadata = pd.read_csv(billionaire_metadata_path)
bronze_billionaire_df = pd.DataFrame(billionaire_metadata) 
bronze_billionaire_df.head(2) #table is already sorted by net-worth
# Out:
#          Name  NetWorth        Country         Source  Rank   Age  \
# 0  Jeff Bezos     177.0  United States         Amazon     1  57.0
# 1   Elon Musk     151.0  United States  Tesla, SpaceX     2  49.0
#
#              Residence    Citizenship           Status  Children  \
# 0  Seattle, Washington  United States  In Relationship       4.0
# 1        Austin, Texas  United States  In Relationship       7.0
#
#                                            Education Self_made  \
# 0     Bachelor of Arts/Science, Princeton University      True
# 1  Bachelor of Arts/Science, University of Pennsy...      True
#
#                                 geometry
# 0        POINT (-122.3300624 47.6038321)
# 1  POINT (-97.74369950000001 30.2711286)

# %%
bronze_billionaire_df.isnull().sum()
# Out:
# Name              0
# NetWorth          0
# Country           0
# Source            0
# Rank              0
# Age             125
# Residence        40
# Citizenship      16
# Status          665
# Children       1203
# Education      1346
# Self_made        18
# geometry          0
# dtype: int64

# %%
#persist the raw-unmodified data to the database

password="postgres"
engine = create_engine(f'postgresql://postgres:{password}@localhost:5432/Billionaire')
connection = engine.connect()
bronze_billionaire_df.to_sql(name='bronze_billionaire', con=engine, if_exists='replace', index=False)

# %%
#Clone to bronze table to proceed with work on the silver version of the data

silver_billionaire_df = bronze_billionaire_df.copy()

# %%
#Rename columns
silver_billionaire_df.rename(columns={"Name"      : "Display_Name", 
                                      "Source"    : "Source_Of_Wealth",
                                      "Rank"      : "Wealth_Rank",
                                      "Status"    : "Relationship_Status",
                                      "Self_Made" : "Is_Self_Made",
                                      "NetWorth"  : "Net_Worth",
                                      "Self_made" : "Is_Self_Made",
                                      "geometry"  : "Geometry"},inplace=True)
silver_billionaire_df.head(2)
# Out:
#   Display_Name  Net_Worth        Country Source_Of_Wealth  Wealth_Rank   Age  \
# 0   Jeff Bezos      177.0  United States           Amazon            1  57.0
# 1    Elon Musk      151.0  United States    Tesla, SpaceX            2  49.0
#
#              Residence    Citizenship Relationship_Status  Children  \
# 0  Seattle, Washington  United States     In Relationship       4.0
# 1        Austin, Texas  United States     In Relationship       7.0
#
#                                            Education Is_Self_Made  \
# 0     Bachelor of Arts/Science, Princeton University         True
# 1  Bachelor of Arts/Science, University of Pennsy...         True
#
#                                 Geometry
# 0        POINT (-122.3300624 47.6038321)
# 1  POINT (-97.74369950000001 30.2711286)

# %%
#Check for duplicates in silver data

dupes_df = silver_billionaire_df.groupby('Display_Name').filter(lambda x: len(x) > 1).sort_values(by=['Display_Name'])
display(dupes_df)
# Out:
#                Display_Name  Net_Worth         Country  \
# 693                   Li Li        4.2           China
# 1976                  Li Li        1.6           China
# 1331          Robert Miller        2.4  United Kingdom
# 1625          Robert Miller        2.0          Canada
# 700   Wang Yanqing & family        4.2           China
# 1919  Wang Yanqing & family        1.7           China
#
#             Source_Of_Wealth  Wealth_Rank   Age         Residence Citizenship  \
# 693               healthcare          680  57.0   Shenzhen, China       China
# 1976         pharmaceuticals         1931  57.0   Shenzhen, China       China
# 1331                  retail         1299  75.0  Montreal, Canada      Canada
# 1625  electronics components         1580  75.0  Montreal, Canada      Canada
# 700     electrical equipment          680  55.0       Wuxi, China       China
# 1919   carbon fiber products         1833  55.0       Wuxi, China       China
#
#      Relationship_Status  Children  \
# 693              Married       NaN
# 1976             Married       NaN
# 1331            Divorced       2.0
# 1625            Divorced       2.0
# 700              Married       NaN
# 1919             Married       NaN
#
#                                          Education Is_Self_Made  \
# 693   Bachelor of Arts/Science, Sichuan University         True
# 1976  Bachelor of Arts/Science, Sichuan University         True
# 1331    Bachelor of Arts/Science, Rider University         True
# 1625    Bachelor of Arts/Science, Rider University         True
# 700                                            NaN         True
# 1919                                           NaN         True
#
#                                    Geometry
# 693           POINT (114.0543297 22.555454)
# 1976          POINT (114.0543297 22.555454)
# 1331  POINT (-73.61036420000001 45.4972159)
# 1625  POINT (-73.61036420000001 45.4972159)
# 700          POINT (120.3074357 31.4933074)
# 1919         POINT (120.3074357 31.4933074)

# %%
#Remove duplidates from Silver

silver_billionaire_df.drop_duplicates(subset="Display_Name",keep=False,inplace=True)

# %%
#Drop billionaires from Silver without a value for Residence and Age

silver_billionaire_df.dropna(subset = ['Residence','Age'],inplace=True)
silver_billionaire_df.isnull().sum()
# Out:
# Display_Name              0
# Net_Worth                 0
# Country                   0
# Source_Of_Wealth          0
# Wealth_Rank               0
# Age                       0
# Residence                 0
# Citizenship               0
# Relationship_Status     566
# Children               1076
# Education              1227
# Is_Self_Made              1
# Geometry                  0
# dtype: int64

# %%
#Clean the Name column and remove reference for "& family" and "family"
#Source: https://stackoverflow.com/questions/37593550/replace-method-not-working-on-pandas-dataframe

silver_billionaire_df["Display_Name"].replace({"& family": '', "family": ''}, inplace=True, regex=True)
silver_billionaire_df["Display_Name"] = silver_billionaire_df["Display_Name"].str.strip()
silver_billionaire_df.head(2)
# Out:
#   Display_Name  Net_Worth        Country Source_Of_Wealth  Wealth_Rank   Age  \
# 0   Jeff Bezos      177.0  United States           Amazon            1  57.0
# 1    Elon Musk      151.0  United States    Tesla, SpaceX            2  49.0
#
#              Residence    Citizenship Relationship_Status  Children  \
# 0  Seattle, Washington  United States     In Relationship       4.0
# 1        Austin, Texas  United States     In Relationship       7.0
#
#                                            Education Is_Self_Made  \
# 0     Bachelor of Arts/Science, Princeton University         True
# 1  Bachelor of Arts/Science, University of Pennsy...         True
#
#                                 Geometry
# 0        POINT (-122.3300624 47.6038321)
# 1  POINT (-97.74369950000001 30.2711286)

# %%
#Create new columns for first name, middle name, and last name
df1 = pd.DataFrame(columns=['First_Name','Middle_Name','Last_Name','Suffix'])
silver_billionaire_df = silver_billionaire_df.join(df1, how="outer")

# %%
#Explode the name column to populate first name, middle name, last name, and suffix where appropriate

for (idx, data_row) in silver_billionaire_df.iterrows():
    
    name_parts = data_row["Display_Name"].split()
    
    if len(name_parts) == 2:
        
        silver_billionaire_df.at[idx,'First_Name'] = name_parts[0]
        silver_billionaire_df.at[idx,'Last_Name']  = name_parts[1]       

    elif len(name_parts) == 3:
        
        silver_billionaire_df.at[idx,'First_Name']  = name_parts[0]
        
        if "," in name_parts[1]:
            
            cleaned_name = name_parts[1].replace(",",'')
            suffix = name_parts[2]
            
            silver_billionaire_df.at[idx,'First_Name'] = name_parts[0]
            silver_billionaire_df.at[idx,'Last_Name']  = cleaned_name
            silver_billionaire_df.at[idx,'Suffix']     = suffix         
            
        else:
            silver_billionaire_df.at[idx,'First_Name']  = name_parts[0]
            silver_billionaire_df.at[idx,'Middle_Name'] = name_parts[1]
            silver_billionaire_df.at[idx,'Last_Name']   = name_parts[2]

# %%
#Create new columns for longitude and latitude
df1 = pd.DataFrame(columns=['Longitude','Latitude'])
silver_billionaire_df = silver_billionaire_df.join(df1, how="outer")

# %%
#Pull out latitude and longitude from geometry column to aide future accessibility to those values

for (idx, data_row) in silver_billionaire_df.iterrows():

    point_parts = data_row["Geometry"].split(" ")

    longitude = str(point_parts[1]).replace("(",'') #longitude
    latitude  = str(point_parts[2]).replace(")",'') #latitude
    
    silver_billionaire_df.at[idx,'Longitude'] = longitude
    silver_billionaire_df.at[idx,'Latitude']  = latitude

# %%
silver_billionaire_df.head(2)
# Out:
#   Display_Name  Net_Worth        Country Source_Of_Wealth  Wealth_Rank   Age  \
# 0   Jeff Bezos      177.0  United States           Amazon            1  57.0
# 1    Elon Musk      151.0  United States    Tesla, SpaceX            2  49.0
#
#              Residence    Citizenship Relationship_Status  Children  \
# 0  Seattle, Washington  United States     In Relationship       4.0
# 1        Austin, Texas  United States     In Relationship       7.0
#
#                                            Education Is_Self_Made  \
# 0     Bachelor of Arts/Science, Princeton University         True
# 1  Bachelor of Arts/Science, University of Pennsy...         True
#
#                                 Geometry First_Name Middle_Name Last_Name  \
# 0        POINT (-122.3300624 47.6038321)       Jeff         NaN     Bezos
# 1  POINT (-97.74369950000001 30.2711286)       Elon         NaN      Musk
#
#   Suffix           Longitude    Latitude
# 0    NaN        -122.3300624  47.6038321
# 1    NaN  -97.74369950000001  30.2711286

# %%
#reorder dataframe columns

#silver_billionaire_df = silver_billionaire_df.reindex(columns=['Display_Name',
                                                               #'First_Name',
                                                               #'Middle_Name',
                                                               #'Last_Name',
                                                               #'Suffix',
                                                               #'Net_Worth',
                                                               #'Country',
                                                               #'Residence',
                                                               #'Citizenship',
                                                               #'Source_Of_Wealth',
                                                               #'Wealth_Rank',
                                                               #'Age',
                                                               #'Relationship_Status',
                                                               #'Children',
                                                               #'Education',
                                                               #'Is_Self_Made',
                                                               #'Geometry',
                                                               #'Longitude',
                                                               #'Latitude'])

# %%
password="postgres"
engine = create_engine(f'postgresql://postgres:{password}@localhost:5432/Billionaire')
connection = engine.connect()
silver_billionaire_df.to_sql(name='silver_billionaire', con=engine, if_exists='append',index='Display_Name')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in insert_data(self)
#     899             try:
# --> 900                 temp.reset_index(inplace=True)
#     901             except ValueError as err:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    5793
# -> 5794                 new_obj.insert(0, name, level_values)
#    5795
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    4408             # Should this be a different kind of error??
# -> 4409             raise ValueError(f"cannot insert {column}, already exists")
#    4410         if not isinstance(loc, int):
#
# ValueError: cannot insert Display_Name, already exists
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9184/3729771758.py in <module>
#       2 engine = create_engine(f'postgresql://postgres:{password}@localhost:5432/Billionaire')
#       3 connection = engine.connect()
# ----> 4 silver_billionaire_df.to_sql(name='silver_billionaire', con=engine, if_exists='append',index='Display_Name')
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2870         from pandas.io import sql
#    2871
# -> 2872         sql.to_sql(
#    2873             self,
#    2874             name,
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     715         )
#     716
# --> 717     pandas_sql.to_sql(
#     718         frame,
#     719         name,
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1759         )
#    1760
# -> 1761         sql_engine.insert_records(
#    1762             table=table,
#    1763             con=self.connectable,
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1338
#    1339         try:
# -> 1340             table.insert(chunksize=chunksize, method=method)
#    1341         except exc.SQLAlchemyError as err:
#    1342             # GH34431
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     943             raise ValueError(f"Invalid parameter `method`: {method}")
#     944
# --> 945         keys, data_list = self.insert_data()
#     946
#     947         nrows = len(self.frame)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in insert_data(self)
#     900                 temp.reset_index(inplace=True)
#     901             except ValueError as err:
# --> 902                 raise ValueError(f"duplicate name in index/columns: {err}") from err
#     903         else:
#     904             temp = self.frame
#
# ValueError: duplicate name in index/columns: cannot insert Display_Name, already exists
